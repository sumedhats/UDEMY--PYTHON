# %% [markdown]
# <a href="https://colab.research.google.com/github/sumedhats/PYTHON-/blob/main/DAY_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def hangman():
    words = ["python", "java", "kotlin", "javascript"]
    chosen_word = random.choice(words)
    guessed_letters = []
    tries = 6

    while tries > 0:
        display = ''.join([letter if letter in guessed_letters else '_' for letter in chosen_word])
        print(display)
        guess = input("Guess a letter: ").lowera
         ()

        if guess in guessed_letters:
            print("You've already guessed that letter.")
        elif guess in chosen_word:
            guessed_letters.append(guess)
            print("Good guess!")
        else:
            guessed_letters.append(guess)
            tries -= 1
            print(f"Wrong guess! You have {tries} tries left.")

        if all(letter in guessed_letters for letter in chosen_word):
            print(f"You win! The word was {chosen_word}.")
            break
    else:
        print(f"You lost! The word was {chosen_word}.")

hangman()
# Out:
# ____
# Guess a letter: j
# Good guess!
# j___
# Guess a letter: a
# Good guess!
# ja_a
# Guess a letter: v
# Good guess!
# You win! The word was java.
